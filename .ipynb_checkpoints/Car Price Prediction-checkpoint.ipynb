# %%
#!pip install selenium

# %%
# import libraraies

import selenium
from selenium import webdriver
import pandas as pd

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings('ignore')
import time

# %%
# lets connect to driver

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.maximize_window()

url='https://www.olx.in/items/q-cars?isSearchCall=true'
driver.get(url)

# %%
link= driver.find_elements_by_xpath('//li[@class="EIR5N"]/a')

# %%
url=[]
for i in link:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 500

# %%
name=[]
manufacture=[]
model=[]
fuel=[]
driven=[]
automatic=[]
owner=[]
location=[]
postingdate=[]
price=[]


for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        title= driver.find_element_by_class_name('_35xN1')
        name.append(title.text.split('(')[0])
        
    except NoSuchElementException:
        name.append('-')
        
    try:
        title= driver.find_element_by_class_name('_35xN1')
        manufacture.append(title.text.split('(')[1].replace(')',''))
    except NoSuchElementException:
        manufacture.append('-')
        
      
    try:
        Model=driver.find_element_by_class_name('_3tLee')
        model.append(Model.text)
    except NoSuchElementException:
        model.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        fuel.append(tab.text.split('\n')[0])
    except NoSuchElementException:
        fuel.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        driven.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        driven.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        automatic.append(tab.text.split('\n')[2])
    except NoSuchElementException:
        automatic.append('-')
        
    try:
        Owner=driver.find_element_by_xpath('//div[@class="_1l939"]/div[1]/div[2]/div[2]')
        owner.append(Owner.text)
    except NoSuchElementException:
        owner.append('-')
        
    try:
        Location=driver.find_element_by_xpath('//div[@class="_1l939"]/div[2]/div[2]/div[2]')
        location.append(Location.text)
    except NoSuchElementException:
        location.append('-')
    try:
        Posting=driver.find_element_by_xpath('//div[@class="_1l939"]/div[3]/div[2]/div[2]')
        postingdate.append(Posting.text)
    except NoSuchElementException:
        postingdate.append('-')
        
    try:
        Price=driver.find_element_by_class_name('_3FkyT')
        price.append(Price.text)
    except NoSuchElementException:
        price.append('-')
        
        
        
        
        
        
len(name) , len(model), len(fuel),len(driven),len(automatic) ,len(owner),len(location),len(postingdate),len(price)
# Out:
# (500, 500, 500, 500, 500, 500, 500, 500, 500)

# %%
len(manufacture)
# Out:
# 20

# %%
df=pd.DataFrame({'Name': name,'Manufacture':manufacture,'Model':model,'Fuel':fuel,'Driven':driven,'Automatic':automatic,'Owner':owner,'Location':location,'Posting Date':postingdate,'Price':price})

# %%
# create excel file
file_name = 'olx.xlsx'

# %%
# save data to excel

df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# details one by one

driver.get('https://www.olx.in/item/maruti-suzuki-swift-ldi-2014-diesel-iid-1685939081')
title= driver.find_element_by_class_name('_3FkyT')
title.text
# Out:
# '₹ 2,98,999'

# %% [markdown]
# # Car Dekho

# %%
# lets connect to driver

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.maximize_window()

url='https://www.cardekho.com/used-cars+in+new-delhi'
driver.get(url)

# %%
link= driver.find_elements_by_xpath('//div[@class=" gsc_row minheight"]/div/a')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001C3564D4340>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-242-6eaa3d11f96b> in <module>
# ----> 1 link= driver.find_elements_by_xpath('//div[@class=" gsc_row minheight"]/div/a')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     542             stacklevel=2,
#     543         )
# --> 544         return self.find_elements(by=By.XPATH, value=xpath)
#     545
#     546     def find_element_by_link_text(self, link_text) -> WebElement:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1281         # Return empty list if driver returns null
#    1282         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1283         return self.execute(Command.FIND_ELEMENTS, {
#    1284             'using': by,
#    1285             'value': value})['value'] or []
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     421
#     422         params = self._wrap_value(params)
# --> 423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
#     425             self.error_handler.check_response(response)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     331         data = utils.dump_json(params)
#     332         url = f"{self._url}{path}"
# --> 333         return self._request(command_info[0], url, body=data)
#     334
#     335     def _request(self, method, url, body=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     353
#     354         if self.keep_alive:
# --> 355             resp = self._conn.request(method, url, body=body, headers=headers)
#     356             statuscode = resp.status
#     357         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     781                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#     785                 url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     781                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#     785                 url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     781                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#     785                 url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753                 e = ProtocolError("Connection aborted.", e)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#     576         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=50584): Max retries exceeded with url: /session/4907ee82b351674776ee06491bbb12c6/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001C3564D4340>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %%
url=[]
for i in link:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 200

# %%
name=[]
manufacture=[]
model=[]
fuel=[]
driven=[]
automatic=[]
owner=[]
location=[]
postingdate=[]
price=[]


for i in url:
    driver.get(i)
    time.sleep(2)
    # Name
    try:
        title= driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div/h1')
        name.append(title.text.split(' ',1)[1])
        
    except NoSuchElementException:
        name.append('-')
        
    # Manufacture year 
    try:
        title= driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div/h1')
        manufacture.append(title.text.split(' ',1)[0])
    except NoSuchElementException:
        manufacture.append('-')
        
    # Model
    try:
        Model=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div')
        model.append(Model.text.split('\n')[1])
    except NoSuchElementException:
        model.append('-')
       
    # Fuel Type
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]')
        fuel.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        fuel.append('-')
        
    # KM Driven
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[4]')
        driven.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        driven.append('-')
        
    # Automatic/ Manual
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[8]')
        automatic.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        automatic.append('-')
      
    # Owner count
    try:
        Owner=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[6]')
        owner.append(Owner.text.split('\n')[1])
    except NoSuchElementException:
        owner.append('-')
      
    # Location
    try:
        Location=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[7]')
        location.append(Location.text.split('\n')[1])
    except NoSuchElementException:
        location.append('-')
        
    # Posting
    try:
        Posting=driver.find_element_by_xpath('//div[@class="_1l939"]/div[3]/div[2]/div[2]')
        postingdate.append(Posting.text)
    except NoSuchElementException:
        postingdate.append('-')
        
    # Price
    try:
        Price=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div[2]/div/div')
        price.append(Price.text.split('\n')[0])
    except NoSuchElementException:
        price.append('-')
        
        
        
        
        
        
len(name) , len(model), len(fuel),len(driven),len(automatic) ,len(owner),len(location),len(postingdate),len(price)
# Out:
# (20, 20, 20, 20, 20, 20, 20, 20, 20)

# %%
data=pd.DataFrame({'Name': name,'Manufacture':manufacture,'Model':model,'Fuel':fuel,'Driven':driven,'Automatic':automatic,'Owner':owner,'Location':location,'Posting Date':postingdate,'Price':price})

# %%
data
# Out:
#                Name Manufacture          Model    Fuel      Driven  Automatic  \
# 0     Maruti Baleno        2018      1.2 Alpha  Petrol   9,541 Kms     Manual
# 1   Maruti Alto 800        2015            VXI  Petrol  59,500 Kms     Manual
# 2       Maruti Ciaz        2018      1.4 Sigma  Petrol  19,880 Kms     Manual
# 3       Hyundai i10        2014    Sportz 1.1L  Petrol  33,764 Kms     Manual
# 4     Renault Kiger        2021        RXT AMT  Petrol   5,799 Kms  Automatic
# 5     Maruti Baleno        2017           Zeta  Petrol  48,459 Kms     Manual
# 6   Volkswagen Polo        2017         GT TSI  Petrol  49,916 Kms  Automatic
# 7      Maruti Swift        2015        VVT VXI  Petrol  43,832 Kms     Manual
# 8     Maruti Baleno        2018      1.2 Delta  Petrol  53,533 Kms     Manual
# 9       Hyundai i20        2016       Asta 1.2  Petrol  40,675 Kms     Manual
# 10       Honda City        2015  i VTEC CVT VX  Petrol  61,969 Kms  Automatic
# 11        MG Hector        2019      Sharp DCT  Petrol  34,880 Kms  Automatic
# 12    Maruti Baleno        2017      1.2 Delta  Petrol  22,258 Kms     Manual
# 13      Hyundai i20        2018      1.2 Spotz  Petrol  69,239 Kms     Manual
# 14                -           -              -       -           -          -
# 15                -           -              -       -           -          -
# 16                -           -              -       -           -          -
# 17                -           -              -       -           -          -
# 18                -           -              -       -           -          -
# 19                -           -              -       -           -          -
#
#         Owner Location Posting Date        Price
# 0   1st Owner     DL5C            -   ₹ 7,19,000
# 1   1st Owner     HR72            -   ₹ 2,85,000
# 2   1st Owner     DL9C            -   ₹ 7,80,000
# 3   2nd Owner     HR03            -   ₹ 3,23,000
# 4   1st Owner     DL3C            -   ₹ 8,02,000
# 5   1st Owner     HR72            -   ₹ 6,11,000
# 6   1st Owner     UP16            -   ₹ 7,03,000
# 7   1st Owner     DL2C            -   ₹ 4,45,000
# 8   1st Owner     DL3C            -   ₹ 5,60,000
# 9   1st Owner     HR51            -   ₹ 5,84,000
# 10  1st Owner     DL14            -   ₹ 7,18,000
# 11  1st Owner     DL8C            -  ₹ 16,61,000
# 12  2nd Owner     HR26            -   ₹ 6,00,000
# 13  1st Owner     UP14            -   ₹ 5,65,000
# 14          -        -            -            -
# 15          -        -            -            -
# 16          -        -            -            -
# 17          -        -            -            -
# 18          -        -            -            -
# 19          -        -            -            -

# %%
# details one by one

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.get('https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Alpha-cars-New-Delhi_785fa298-10bb-4099-b6ec-6def9c8a1a6d.htm')

# %%
title= driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]')
title.text.split('\n')[1]
# Out:
# 'Petrol'
